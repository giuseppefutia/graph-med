# %% [markdown]
# # Installation, Importing, Configuration

# %%
# %%capture
# !pip install -qq fastapi uvicorn
# !pip install -qq vllm
# !pip install -qq pyngrok

# %%
from __future__ import annotations

# Standard library
import os
import socket
import subprocess
import sys
import textwrap
import time
from contextlib import contextmanager
from dataclasses import dataclass
from getpass import getpass
from typing import Iterable, Generator, Optional, Sequence

# Third-party
import torch
from pyngrok import ngrok
from fastapi import FastAPI
from fastapi.responses import JSONResponse, StreamingResponse
from fastapi.middleware.cors import CORSMiddleware
from pydantic import BaseModel
from openai import OpenAI
from huggingface_hub import login
from google.colab import userdata
import uvicorn

# %%
# You need to store your keys into Secret section
HF_TOKEN = userdata.get("HF_TOKEN")
NGROK_TOKEN = userdata.get("NGROK_TOKEN")
NGROK_DOMAIN = userdata.get("NGROK_QWEN_DOMAIN")

os.environ["HF_TOKEN"] = HF_TOKEN
os.environ["NGROK_TOKEN"] = NGROK_TOKEN

login(HF_TOKEN)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# !ngrok config add-authtoken "$NGROK_TOKEN"
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
MODEL = 'Alibaba-NLP/gte-Qwen2-7B-instruct' # @param {type:'string'}
VLLM_HOST = '0.0.0.0' # @param {type:'string'}
VLLM_PORT = 8000 # @param {type:'integer'}
API_HOST = '127.0.0.1' # @param {type:'string'}
API_PORT = 8001 # @param {type:'integer'}
MAX_MODEL_LEN = 32768 # @param {type:'integer'}
TENSOR_PARALLEL_SIZE = 1 # @param {type:'integer'}

# %% [markdown]
# # Embedding Model Deployment with vLLM

# %%
# ----------------------------
# Config (simple, safe defaults for Colab)
# ----------------------------
from dataclasses import dataclass
from typing import Optional, Sequence, Generator, Tuple, List
import subprocess, time, socket, torch
from contextlib import contextmanager
from threading import Thread

@dataclass
class VLLMConfig:
    model: str = MODEL
    host: str = VLLM_HOST
    port: int = VLLM_PORT
    max_model_len: int = MAX_MODEL_LEN
    tensor_parallel_size: int = TENSOR_PARALLEL_SIZE
    trust_remote_code: bool = True
    download_dir: Optional[str] = None
    served_model_name: Optional[str] = None

    @property
    def base_url(self) -> str:
        return f"http://{self.host}:{self.port}"

# ----------------------------
# Small helpers (no filesystem/log files)
# ----------------------------
def select_dtype() -> str:
    if torch.cuda.is_available():
        major, _ = torch.cuda.get_device_capability(0)
        return "bfloat16" if major >= 8 else "float16"
    return "float32"

def wait_for_port(host: str, port: int, timeout: float = 120.0, interval: float = 0.5) -> bool:
    deadline = time.time() + timeout
    while time.time() < deadline:
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
            s.settimeout(1.0)
            if s.connect_ex((host, port)) == 0:
                return True
        time.sleep(interval)
    return False

def build_args(cfg: VLLMConfig, dtype: str) -> Sequence[str]:
    args = [
        "vllm", "serve", cfg.model,
        "--dtype", dtype,
        "--max-model-len", str(cfg.max_model_len),
        "--tensor-parallel-size", str(cfg.tensor_parallel_size),
        "--host", cfg.host,
        "--port", str(cfg.port),
    ]
    if cfg.trust_remote_code:
        args.append("--trust-remote-code")
    if cfg.download_dir:
        args += ["--download-dir", cfg.download_dir]
    if cfg.served_model_name:
        args += ["--served-model-name", cfg.served_model_name]
    return args

# ----------------------------
# Log streaming helpers
# ----------------------------
def _pump(pipe, tag: str, sink: Optional[List[str]] = None):
    """Read a subprocess pipe line-by-line and stream it to stdout (and optional sink)."""
    try:
        for line in iter(pipe.readline, ""):
            if not line:
                break
            print(f"[vLLM {tag}] {line}", end="")   # stream to cell output
            if sink is not None:
                sink.append(f"[{tag}] {line}")
    except Exception as e:
        print(f"[vLLM LOG ERROR {tag}] {e}")
    finally:
        try:
            pipe.close()
        except Exception:
            pass

class VLLMProcess:
    """Wrapper for the vLLM subprocess that also carries in-memory logs."""
    def __init__(self, proc: subprocess.Popen):
        self.proc = proc
        self.logs: List[str] = []
        self._t_out = Thread(target=_pump, args=(proc.stdout, "OUT", self.logs), daemon=True)
        self._t_err = Thread(target=_pump, args=(proc.stderr, "ERR", self.logs), daemon=True)
        self._t_out.start()
        self._t_err.start()

    @property
    def pid(self) -> int:
        return self.proc.pid

    def wait(self, timeout: Optional[float] = None) -> int:
        return self.proc.wait(timeout=timeout)

# ----------------------------
# Start/stop + context manager (with live logs)
# ----------------------------
def start_vllm(cfg: VLLMConfig) -> VLLMProcess:
    dtype = select_dtype()
    args = build_args(cfg, dtype)
    proc = subprocess.Popen(
        args,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        encoding="utf-8",
        errors="replace",
        start_new_session=True,
        bufsize=1,          # line-buffered for timely streaming
    )
    return VLLMProcess(proc)

def stop_vllm(p: Optional[VLLMProcess]) -> None:
    if not p:
        return
    proc = p.proc
    try:
        proc.terminate()
        try:
            proc.wait(timeout=10)
        except subprocess.TimeoutExpired:
            proc.kill()
    except Exception:
        pass

@contextmanager
def run_vllm(cfg: VLLMConfig) -> Generator[Tuple[str, VLLMProcess], None, None]:
    """Start vLLM, stream logs live, yield (base_url, process), then clean up."""
    p = start_vllm(cfg)
    try:
        if not wait_for_port(cfg.host, cfg.port, timeout=600):
            stop_vllm(p)
            raise RuntimeError("vLLM didn't become ready on time. (Port check failed)")
        print(f"vLLM up at {cfg.base_url} (pid={p.pid})")
        yield (cfg.base_url, p)
    finally:
        stop_vllm(p)

# %%
cfg = VLLMConfig(model=MODEL, port=VLLM_PORT)

with run_vllm(cfg) as (base_url, p):  # p is VLLMProcess (has .proc, .pid, .logs)
    print("Server is ready at:", base_url)

    # OpenAI-compatible client pointing to local vLLM
    client = OpenAI(base_url=f"{base_url}/v1", api_key="EMPTY")  # api_key is ignored by vLLM

    # Use the served alias if you set one; otherwise the model id
    served_name = cfg.served_model_name or cfg.model

    out = client.embeddings.create(
        model=served_name,  # e.g. "Alibaba-NLP/gte-Qwen2-7B-instruct"
        input=[
            "A cozy coffee shop with brick walls.",
            "The capital of Italy is Rome."
        ],
    )

    print(len(out.data[0].embedding), len(out.data[1].embedding))
# Out:
# [vLLM ERR] 2026-03-17 06:06:51.119661: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# [vLLM ERR] 2026-03-17 06:06:51.138433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# [vLLM ERR] WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# [vLLM ERR] E0000 00:00:1773727611.163858    2214 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# [vLLM ERR] E0000 00:00:1773727611.171216    2214 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [vLLM ERR] W0000 00:00:1773727611.188922    2214 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727611.188960    2214 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727611.188962    2214 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727611.188964    2214 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] 2026-03-17 06:06:51.193968: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# [vLLM ERR] To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]        █     █     █▄   ▄█
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.17.1
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]   █▄█▀ █     █     █     █  model   Alibaba-NLP/gte-Qwen2-7B-instruct
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:302]
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:11 [utils.py:238] non-default args: {'model_tag': 'Alibaba-NLP/gte-Qwen2-7B-instruct', 'host': '0.0.0.0', 'model': 'Alibaba-NLP/gte-Qwen2-7B-instruct', 'trust_remote_code': True, 'dtype': 'bfloat16', 'max_model_len': 32768}
# [vLLM ERR] (APIServer pid=2214) The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# [vLLM ERR] (APIServer pid=2214) The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:12 [config.py:882] Found sentence-transformers tokenize configuration.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:33 [config.py:770] Found sentence-transformers modules configuration.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [config.py:797] Found pooling configuration.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [model.py:804] Resolved `--runner auto` to `--runner pooling`. Pass the value explicitly to silence this message.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [model.py:856] Resolved `--convert auto` to `--convert embed`. Pass the value explicitly to silence this message.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [model.py:531] Resolved architecture: Qwen2ForCausalLM
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [model.py:1889] Downcasting torch.float32 to torch.bfloat16.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [model.py:1554] Using max model len 32768
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:07:34 [vllm.py:747] Asynchronous scheduling is enabled.
# [vLLM OUT] (APIServer pid=2214) WARNING 03-17 06:07:34 [vllm.py:909] Pooling models do not support full cudagraphs. Overriding cudagraph_mode to PIECEWISE.
# [vLLM ERR] (APIServer pid=2214) A new version of the following files was downloaded from https://huggingface.co/Alibaba-NLP/gte-Qwen2-7B-instruct:
# [vLLM ERR] (APIServer pid=2214) - tokenization_qwen.py
# [vLLM ERR] (APIServer pid=2214) . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [vLLM ERR] 2026-03-17 06:07:41.038761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# [vLLM ERR] WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# [vLLM ERR] E0000 00:00:1773727661.065435    2556 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# [vLLM ERR] E0000 00:00:1773727661.072767    2556 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [vLLM ERR] W0000 00:00:1773727661.089568    2556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727661.089603    2556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727661.089605    2556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727661.089607    2556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:53 [core.py:101] Initializing a V1 LLM engine (v0.17.1) with config: model='Alibaba-NLP/gte-Qwen2-7B-instruct', speculative_config=None, tokenizer='Alibaba-NLP/gte-Qwen2-7B-instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Alibaba-NLP/gte-Qwen2-7B-instruct, enable_prefix_caching=False, enable_chunked_prefill=False, pooler_config=PoolerConfig(pooling_type=None, seq_pooling_type='LAST', tok_pooling_type='ALL', use_activation=True, dimensions=None, enable_chunked_processing=False, max_embed_len=None, logit_bias=None, step_tag_id=None, returned_token_ids=None), compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [32768], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.PIECEWISE: 1>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:53 [parallel_state.py:1393] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:52053 backend=nccl
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:53 [parallel_state.py:1715] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:54 [base.py:106] Offloader set to NoopOffloader
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:54 [gpu_model_runner.py:4281] Starting to load model Alibaba-NLP/gte-Qwen2-7B-instruct...
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:55 [cuda.py:405] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:07:55 [flash_attn.py:587] Using FlashAttention version 2
# [vLLM ERR] (EngineCore_DP0 pid=2556) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# [vLLM ERR] (EngineCore_DP0 pid=2556) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:17 [weight_utils.py:561] Time spent downloading weights for Alibaba-NLP/gte-Qwen2-7B-instruct: 81.590217 seconds
# [vLLM ERR] (EngineCore_DP0 pid=2556)
# [vLLM ERR] Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# [vLLM ERR] (EngineCore_DP0 pid=2556)
# [vLLM ERR] Loading safetensors checkpoint shards: 100% Completed | 7/7 [00:00<00:00, 426.26it/s]
# [vLLM ERR] (EngineCore_DP0 pid=2556)
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:24 [default_loader.py:293] Loading weights took 6.80 seconds
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:25 [gpu_model_runner.py:4364] Model loading took 13.25 GiB memory and 89.950071 seconds
# [vLLM ERR] (EngineCore_DP0 pid=2556)
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:34 [backends.py:916] Using cache directory: /root/.cache/vllm/torch_compile_cache/a85b90bdd1/rank_0_0/backbone for vLLM's torch.compile
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:34 [backends.py:976] Dynamo bytecode transform time: 8.36 s
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:41 [backends.py:350] Cache the graph of compile range (1, 32768) for later use
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:47 [backends.py:366] Compiling a graph for compile range (1, 32768) takes 11.46 s
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:47 [monitor.py:35] torch.compile takes 21.07 s in total
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:47 [decorators.py:580] saving AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/fc852dec92140d1c5aede42d60edd71664ea315f844128b558bc7396d1665ee3/rank_0_0/model
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:48 [decorators.py:588] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/fc852dec92140d1c5aede42d60edd71664ea315f844128b558bc7396d1665ee3/rank_0_0/model
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   0%|          | 0/51 [00:00<?, ?it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   2%|▏         | 1/51 [00:22<18:51, 22.64s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   6%|▌         | 3/51 [00:22<04:44,  5.92s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  10%|▉         | 5/51 [00:22<02:13,  2.91s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  14%|█▎        | 7/51 [00:23<01:14,  1.70s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  18%|█▊        | 9/51 [00:23<00:45,  1.08s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  22%|██▏       | 11/51 [00:23<00:28,  1.38it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  25%|██▌       | 13/51 [00:23<00:19,  2.00it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  29%|██▉       | 15/51 [00:23<00:12,  2.80it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  33%|███▎      | 17/51 [00:23<00:08,  3.83it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  39%|███▉      | 20/51 [00:23<00:05,  5.71it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  45%|████▌     | 23/51 [00:23<00:03,  7.76it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  49%|████▉     | 25/51 [00:23<00:02,  8.88it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  55%|█████▍    | 28/51 [00:24<00:02, 11.20it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  61%|██████    | 31/51 [00:24<00:01, 13.30it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  67%|██████▋   | 34/51 [00:24<00:01, 15.15it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  73%|███████▎  | 37/51 [00:24<00:00, 16.70it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  78%|███████▊  | 40/51 [00:24<00:00, 17.81it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  84%|████████▍ | 43/51 [00:24<00:00, 18.59it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  90%|█████████ | 46/51 [00:24<00:00, 19.22it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  96%|█████████▌| 49/51 [00:25<00:00, 18.14it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:25<00:00, 17.35it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:25<00:00,  2.01it/s]
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:52 [gpu_model_runner.py:5386] Graph capturing finished in 27 secs, took 0.34 GiB
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:52 [core.py:282] init engine (profile, create kv cache, warmup model) took 26.74 seconds
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:53 [config.py:882] Found sentence-transformers tokenize configuration.
# [vLLM OUT] (EngineCore_DP0 pid=2556) INFO 03-17 06:09:54 [vllm.py:747] Asynchronous scheduling is enabled.
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [api_server.py:495] Supported tasks: ['embed', 'token_embed']
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [api_server.py:500] Starting vLLM API server 0 on http://0.0.0.0:8000
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:38] Available routes are:
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /openapi.json, Methods: GET, HEAD
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /docs, Methods: GET, HEAD
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /docs/oauth2-redirect, Methods: GET, HEAD
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /redoc, Methods: GET, HEAD
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /tokenize, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /detokenize, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /load, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /version, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /health, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /metrics, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /v1/models, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /ping, Methods: GET
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /ping, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /invocations, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /pooling, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /v1/embeddings, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /score, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /v1/score, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /rerank, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /v1/rerank, Methods: POST
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:54 [launcher.py:47] Route: /v2/rerank, Methods: POST
# [vLLM ERR] (APIServer pid=2214) INFO:     Started server process [2214]
# [vLLM ERR] (APIServer pid=2214) INFO:     Waiting for application startup.
# [vLLM ERR] (APIServer pid=2214) INFO:     Application startup complete.
# vLLM up at http://0.0.0.0:8000 (pid=2214)
# Server is ready at: http://0.0.0.0:8000
# [vLLM ERR] (APIServer pid=2214) /usr/local/lib/python3.12/dist-packages/vllm/entrypoints/utils.py:126: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
# [vLLM ERR] (APIServer pid=2214)   return await func(*args, **kwargs)
# [vLLM OUT] (APIServer pid=2214) INFO:     127.0.0.1:35014 - "POST /v1/embeddings HTTP/1.1" 200 OK
# 3584 3584
# [vLLM OUT] (APIServer pid=2214) INFO 03-17 06:09:55 [launcher.py:122] Shutting down FastAPI HTTP server.
# [vLLM ERR] [rank0]:[W317 06:09:55.969184645 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# [vLLM ERR] (APIServer pid=2214) INFO:     Shutting down
# [vLLM ERR] (APIServer pid=2214) INFO:     Waiting for application shutdown.
# [vLLM ERR] (APIServer pid=2214) INFO:     Application shutdown complete.

# %%
from typing import List, Optional, Union
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from fastapi.responses import JSONResponse
from pydantic import BaseModel
from openai import OpenAI

# ---------- Pydantic models ----------
class EmbeddingRequest(BaseModel):
    # Accept a single string or a list of strings; coerce to a list internally
    input: Union[str, List[str]]
    # Optional override of the model per-request; defaults to the app's model_name
    model: Optional[str] = None
    # If True, L2-normalize each embedding before returning
    normalize: bool = False

class MeanPoolRequest(EmbeddingRequest):
    # Same fields; this endpoint returns a single mean-pooled vector
    pass

# ---------- App factory ----------
def build_app(client: OpenAI, model_name: str) -> FastAPI:
    """
    Build a FastAPI that proxies to a vLLM embeddings server via the
    OpenAI-compatible SDK, e.g. client = OpenAI(base_url="http://localhost:8000/v1", api_key="EMPTY")
    """
    app = FastAPI(title="vLLM Embeddings Proxy")

    app.add_middleware(
        CORSMiddleware,
        allow_origins=["*"],   # tighten for production
        allow_credentials=True,
        allow_methods=["*"],
        allow_headers=["*"],
    )

    @app.get("/healthz")
    def healthz():
        return {"status": "ok", "model": model_name}

    # -------- Embedding helpers --------
    def _to_list(x: Union[str, List[str]]) -> List[str]:
        return [x] if isinstance(x, str) else x

    def _l2_normalize(vec: List[float]) -> List[float]:
        # Avoid pulling in numpy just for this
        s = sum(v * v for v in vec) ** 0.5
        return [v / s if s > 0 else 0.0 for v in vec]

    # -------- Endpoints --------
    @app.post("/embed")
    def embed(req: EmbeddingRequest):
        inputs: List[str] = _to_list(req.input)
        mdl = req.model or model_name

        resp = client.embeddings.create(
            model=mdl,
            input=inputs,
        )

        # vLLM follows OpenAI schema: resp.data is a list matching inputs order
        vectors = [d.embedding for d in resp.data]
        if req.normalize:
            vectors = [_l2_normalize(v) for v in vectors]

        payload = {
            "model": resp.model,
            "num_inputs": len(inputs),
            "embedding_dims": len(vectors[0]) if vectors else 0,
            "data": vectors,  # List[List[float]]
        }
        return JSONResponse(payload)

    @app.post("/embed/mean")
    def embed_mean(req: MeanPoolRequest):
        inputs: List[str] = _to_list(req.input)
        mdl = req.model or model_name

        resp = client.embeddings.create(
            model=mdl,
            input=inputs,
        )

        vectors = [d.embedding for d in resp.data]
        # Mean-pool across inputs (dimension-wise)
        if not vectors:
            mean_vec: List[float] = []
        else:
            dims = len(vectors[0])
            # Verify consistent dims (defensive)
            assert all(len(v) == dims for v in vectors), "Inconsistent embedding dimensions"
            mean_vec = [sum(v[i] for v in vectors) / len(vectors) for i in range(dims)]

        if req.normalize and mean_vec:
            mean_vec = _l2_normalize(mean_vec)

        payload = {
            "model": resp.model,
            "inputs": len(inputs),
            "embedding_dims": len(mean_vec) if mean_vec else (len(vectors[0]) if vectors else 0),
            "embedding": mean_vec,  # List[float]
        }
        return JSONResponse(payload)

    return app

# %%
cfg = VLLMConfig(model=MODEL, port=VLLM_PORT)
with run_vllm(cfg) as (base_url, proc):   # 'proc' is the VLLMProcess; keep the name as in your original

    client = OpenAI(base_url=f"{base_url}/v1", api_key="EMPTY")
    model_name = cfg.served_model_name or cfg.model

    #public_url = ngrok.connect(API_PORT).public_url
    public_url = ngrok.connect(cfg.port, "http", domain=NGROK_DOMAIN).public_url
    # print(f" * ngrok tunnel \"{public_url}\" -> \"{API_HOST}:{API_PORT}\"")

    app = build_app(client, model_name)
    config = uvicorn.Config(app, host=API_HOST, port=API_PORT, log_level="info")
    server = uvicorn.Server(config)

    await server.serve()
# Out:
# [vLLM ERR] 2026-03-17 06:10:02.556052: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# [vLLM ERR] 2026-03-17 06:10:02.575140: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# [vLLM ERR] WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# [vLLM ERR] E0000 00:00:1773727802.601109    3361 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# [vLLM ERR] E0000 00:00:1773727802.608732    3361 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [vLLM ERR] W0000 00:00:1773727802.626655    3361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727802.626706    3361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727802.626709    3361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727802.626711    3361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] 2026-03-17 06:10:02.631757: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# [vLLM ERR] To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]        █     █     █▄   ▄█
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.17.1
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]   █▄█▀ █     █     █     █  model   Alibaba-NLP/gte-Qwen2-7B-instruct
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:302]
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [utils.py:238] non-default args: {'model_tag': 'Alibaba-NLP/gte-Qwen2-7B-instruct', 'host': '0.0.0.0', 'model': 'Alibaba-NLP/gte-Qwen2-7B-instruct', 'trust_remote_code': True, 'dtype': 'bfloat16', 'max_model_len': 32768}
# [vLLM ERR] (APIServer pid=3361) The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# [vLLM ERR] (APIServer pid=3361) The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [config.py:882] Found sentence-transformers tokenize configuration.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [config.py:770] Found sentence-transformers modules configuration.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [config.py:797] Found pooling configuration.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [model.py:804] Resolved `--runner auto` to `--runner pooling`. Pass the value explicitly to silence this message.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [model.py:856] Resolved `--convert auto` to `--convert embed`. Pass the value explicitly to silence this message.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [model.py:531] Resolved architecture: Qwen2ForCausalLM
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [model.py:1889] Downcasting torch.float32 to torch.bfloat16.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [model.py:1554] Using max model len 32768
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:10:19 [vllm.py:747] Asynchronous scheduling is enabled.
# [vLLM OUT] (APIServer pid=3361) WARNING 03-17 06:10:19 [vllm.py:909] Pooling models do not support full cudagraphs. Overriding cudagraph_mode to PIECEWISE.
# [vLLM ERR] 2026-03-17 06:10:26.246148: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# [vLLM ERR] WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# [vLLM ERR] E0000 00:00:1773727826.271193    3520 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# [vLLM ERR] E0000 00:00:1773727826.278564    3520 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [vLLM ERR] W0000 00:00:1773727826.295546    3520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727826.295584    3520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727826.295587    3520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] W0000 00:00:1773727826.295588    3520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM ERR] AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:38 [core.py:101] Initializing a V1 LLM engine (v0.17.1) with config: model='Alibaba-NLP/gte-Qwen2-7B-instruct', speculative_config=None, tokenizer='Alibaba-NLP/gte-Qwen2-7B-instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Alibaba-NLP/gte-Qwen2-7B-instruct, enable_prefix_caching=False, enable_chunked_prefill=False, pooler_config=PoolerConfig(pooling_type=None, seq_pooling_type='LAST', tok_pooling_type='ALL', use_activation=True, dimensions=None, enable_chunked_processing=False, max_embed_len=None, logit_bias=None, step_tag_id=None, returned_token_ids=None), compilation_config={'level': None, 'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [32768], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.PIECEWISE: 1>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:38 [parallel_state.py:1393] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:49479 backend=nccl
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:38 [parallel_state.py:1715] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:39 [base.py:106] Offloader set to NoopOffloader
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:39 [gpu_model_runner.py:4281] Starting to load model Alibaba-NLP/gte-Qwen2-7B-instruct...
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:40 [cuda.py:405] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:40 [flash_attn.py:587] Using FlashAttention version 2
# [vLLM ERR] (EngineCore_DP0 pid=3520) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# [vLLM ERR] (EngineCore_DP0 pid=3520) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# [vLLM ERR] (EngineCore_DP0 pid=3520)
# [vLLM ERR] Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# [vLLM ERR] (EngineCore_DP0 pid=3520)
# [vLLM ERR] Loading safetensors checkpoint shards: 100% Completed | 7/7 [00:00<00:00, 401.28it/s]
# [vLLM ERR] (EngineCore_DP0 pid=3520)
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:48 [default_loader.py:293] Loading weights took 7.25 seconds
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:49 [gpu_model_runner.py:4364] Model loading took 13.25 GiB memory and 8.574956 seconds
# [vLLM ERR] (EngineCore_DP0 pid=3520)
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:52 [decorators.py:465] Directly load AOT compilation from path /root/.cache/vllm/torch_compile_cache/torch_aot_compile/fc852dec92140d1c5aede42d60edd71664ea315f844128b558bc7396d1665ee3/rank_0_0/model
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:53 [backends.py:916] Using cache directory: /root/.cache/vllm/torch_compile_cache/a85b90bdd1/rank_0_0/backbone for vLLM's torch.compile
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:53 [backends.py:976] Dynamo bytecode transform time: 3.68 s
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:55 [backends.py:266] Directly load the compiled graph(s) for compile range (1, 32768) from the cache, took 1.539 s
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:55 [monitor.py:35] torch.compile takes 5.55 s in total
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   0%|          | 0/51 [00:00<?, ?it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   2%|▏         | 1/51 [00:05<04:39,  5.58s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   6%|▌         | 3/51 [00:05<01:11,  1.50s/it]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  10%|▉         | 5/51 [00:05<00:34,  1.31it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  14%|█▎        | 7/51 [00:05<00:20,  2.16it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  18%|█▊        | 9/51 [00:06<00:13,  3.23it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  22%|██▏       | 11/51 [00:06<00:08,  4.54it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  25%|██▌       | 13/51 [00:06<00:06,  6.09it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  29%|██▉       | 15/51 [00:06<00:04,  7.79it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  33%|███▎      | 17/51 [00:06<00:03,  9.64it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  39%|███▉      | 20/51 [00:06<00:02, 12.40it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  45%|████▌     | 23/51 [00:06<00:01, 14.73it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  51%|█████     | 26/51 [00:06<00:01, 16.14it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  57%|█████▋    | 29/51 [00:07<00:01, 17.75it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  63%|██████▎   | 32/51 [00:07<00:01, 18.71it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  69%|██████▊   | 35/51 [00:07<00:00, 19.42it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  75%|███████▍  | 38/51 [00:07<00:00, 20.14it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  80%|████████  | 41/51 [00:07<00:00, 20.80it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  86%|████████▋ | 44/51 [00:07<00:00, 21.26it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  92%|█████████▏| 47/51 [00:07<00:00, 21.76it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  98%|█████████▊| 50/51 [00:08<00:00, 21.30it/s]
# [vLLM ERR] Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:08<00:00,  6.31it/s]
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:58 [gpu_model_runner.py:5386] Graph capturing finished in 9 secs, took 0.34 GiB
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:58 [core.py:282] init engine (profile, create kv cache, warmup model) took 9.25 seconds
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:10:59 [config.py:882] Found sentence-transformers tokenize configuration.
# [vLLM OUT] (EngineCore_DP0 pid=3520) INFO 03-17 06:11:00 [vllm.py:747] Asynchronous scheduling is enabled.
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [api_server.py:495] Supported tasks: ['token_embed', 'embed']
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [api_server.py:500] Starting vLLM API server 0 on http://0.0.0.0:8000
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:38] Available routes are:
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /openapi.json, Methods: HEAD, GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /docs, Methods: HEAD, GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /redoc, Methods: HEAD, GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /tokenize, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /detokenize, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /load, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /version, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /health, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /metrics, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /v1/models, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /ping, Methods: GET
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /ping, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /invocations, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /pooling, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /v1/embeddings, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /score, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /v1/score, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /rerank, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /v1/rerank, Methods: POST
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:11:00 [launcher.py:47] Route: /v2/rerank, Methods: POST
# [vLLM ERR] (APIServer pid=3361) INFO:     Started server process [3361]
# [vLLM ERR] (APIServer pid=3361) INFO:     Waiting for application startup.
# [vLLM ERR] (APIServer pid=3361) INFO:     Application startup complete.
# vLLM up at http://0.0.0.0:8000 (pid=3361)
# INFO:     Started server process [1632]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8001 (Press CTRL+C to quit)
# [vLLM ERR] (APIServer pid=3361) /usr/local/lib/python3.12/dist-packages/vllm/entrypoints/utils.py:126: FastAPIDeprecationWarning: ORJSONResponse is deprecated, FastAPI now serializes data directly to JSON bytes via Pydantic when a return type or response model is set, which is faster and doesn't need a custom response class. Read more in the FastAPI docs: https://fastapi.tiangolo.com/advanced/custom-response/#orjson-or-response-model and https://fastapi.tiangolo.com/tutorial/response-model/
# [vLLM ERR] (APIServer pid=3361)   return await func(*args, **kwargs)
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:27:40 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:27:50 [loggers.py:259] Engine 000: Avg prompt throughput: 0.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:28:00 [loggers.py:259] Engine 000: Avg prompt throughput: 2.7 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:28:10 [loggers.py:259] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:38:30 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:38:40 [loggers.py:259] Engine 000: Avg prompt throughput: 0.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:38:50 [loggers.py:259] Engine 000: Avg prompt throughput: 2.7 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:39:00 [loggers.py:259] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:39:20 [loggers.py:259] Engine 000: Avg prompt throughput: 0.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:39:30 [loggers.py:259] Engine 000: Avg prompt throughput: 1.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:39:40 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:39:50 [loggers.py:259] Engine 000: Avg prompt throughput: 2.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:00 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:10 [loggers.py:259] Engine 000: Avg prompt throughput: 1.2 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:20 [loggers.py:259] Engine 000: Avg prompt throughput: 1.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:30 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:40 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:40:50 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:00 [loggers.py:259] Engine 000: Avg prompt throughput: 2.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:10 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:20 [loggers.py:259] Engine 000: Avg prompt throughput: 0.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:30 [loggers.py:259] Engine 000: Avg prompt throughput: 2.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:40 [loggers.py:259] Engine 000: Avg prompt throughput: 1.4 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:41:50 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:00 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:10 [loggers.py:259] Engine 000: Avg prompt throughput: 1.4 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:20 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:30 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:40 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:42:50 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:10 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:31 [loggers.py:259] Engine 000: Avg prompt throughput: 1.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.2 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:43:51 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:21 [loggers.py:259] Engine 000: Avg prompt throughput: 2.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:31 [loggers.py:259] Engine 000: Avg prompt throughput: 1.7 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:41 [loggers.py:259] Engine 000: Avg prompt throughput: 2.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:44:51 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:45:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.3 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:45:11 [loggers.py:259] Engine 000: Avg prompt throughput: 14.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 06:45:21 [loggers.py:259] Engine 000: Avg prompt throughput: 13.8 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# ...
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:20:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:20:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:20:31 [loggers.py:259] Engine 000: Avg prompt throughput: 2.2 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:20:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.4 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:20:51 [loggers.py:259] Engine 000: Avg prompt throughput: 1.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:31 [loggers.py:259] Engine 000: Avg prompt throughput: 2.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:21:51 [loggers.py:259] Engine 000: Avg prompt throughput: 0.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:01 [loggers.py:259] Engine 000: Avg prompt throughput: 2.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:11 [loggers.py:259] Engine 000: Avg prompt throughput: 2.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.7 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:31 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:22:51 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.6 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:31 [loggers.py:259] Engine 000: Avg prompt throughput: 1.1 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:23:51 [loggers.py:259] Engine 000: Avg prompt throughput: 1.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.2 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:21 [loggers.py:259] Engine 000: Avg prompt throughput: 1.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:31 [loggers.py:259] Engine 000: Avg prompt throughput: 2.7 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:41 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:24:51 [loggers.py:259] Engine 000: Avg prompt throughput: 2.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:25:01 [loggers.py:259] Engine 000: Avg prompt throughput: 1.9 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO:     2a01:e11:5401:8500:95f8:8617:8047:b5b4:0 - "POST /v1/embeddings HTTP/1.1" 200 OK
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:25:11 [loggers.py:259] Engine 000: Avg prompt throughput: 1.5 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [vLLM OUT] (APIServer pid=3361) INFO 03-17 09:25:21 [loggers.py:259] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
